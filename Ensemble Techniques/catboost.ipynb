# %% [markdown]
# <a href="https://colab.research.google.com/github/yuvashri-Y/ML/blob/main/catboost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
test=pd.read_csv("https://raw.githubusercontent.com/ezioauditore-tech/AI/main/datasets/amazon-employee-access-challenge/test.csv")
train=pd.read_csv("https://raw.githubusercontent.com/ezioauditore-tech/AI/main/datasets/amazon-employee-access-challenge/train.csv")

# %%
test.shape,train.shape
# Out:
# ((58921, 10), (32769, 10))

# %%
test.isnull().sum()
# Out:
# id                  0
# RESOURCE            0
# MGR_ID              0
# ROLE_ROLLUP_1       0
# ROLE_ROLLUP_2       0
# ROLE_DEPTNAME       0
# ROLE_TITLE          0
# ROLE_FAMILY_DESC    0
# ROLE_FAMILY         0
# ROLE_CODE           0
# dtype: int64

# %%
train.isnull().sum()
# Out:
# ACTION              0
# RESOURCE            0
# MGR_ID              0
# ROLE_ROLLUP_1       0
# ROLE_ROLLUP_2       0
# ROLE_DEPTNAME       0
# ROLE_TITLE          0
# ROLE_FAMILY_DESC    0
# ROLE_FAMILY         0
# ROLE_CODE           0
# dtype: int64

# %%
train
# Out:
#        ACTION  RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0           1     39353   85475         117961         118300         123472
# 1           1     17183    1540         117961         118343         123125
# 2           1     36724   14457         118219         118220         117884
# 3           1     36135    5396         117961         118343         119993
# 4           1     42680    5905         117929         117930         119569
# ...       ...       ...     ...            ...            ...            ...
# 32764       1     23497   16971         117961         118300         119993
# 32765       1     25139  311198          91261         118026         122392
# 32766       1     34924   28805         117961         118327         120299
# 32767       1     80574   55643         118256         118257         117945
# 32768       1     14354   59575         117916         118150         117920
#
# ...

# %%
test
# Out:
#           id  RESOURCE  MGR_ID  ROLE_ROLLUP_1  ROLE_ROLLUP_2  ROLE_DEPTNAME  \
# 0          1     78766   72734         118079         118080         117878
# 1          2     40644    4378         117961         118327         118507
# 2          3     75443    2395         117961         118300         119488
# 3          4     43219   19986         117961         118225         118403
# 4          5     42093   50015         117961         118343         119598
# ...      ...       ...     ...            ...            ...            ...
# 58916  58917     75078    4565         117961         118386         121961
# 58917  58918      6977   72209         117961         118225         124948
# 58918  58919     39262    6114         117961         118343           6104
# 58919  58920      1023    8674         117961         118327         120318
# 58920  58921     44977    3918         117961         118343         118660
#
# ...

# %%
x=train.drop('ACTION',axis=1)
y=train['ACTION']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# !pip install catboost
from catboost import CatBoostClassifier
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
model = CatBoostClassifier(iterations=100, learning_rate=0.1, depth=6)
model.fit(x_train, y_train) # fit the model to training data
# Out:
# ...
# 0:	learn: 0.6197557	total: 6.32ms	remaining: 626ms
# 1:	learn: 0.5594312	total: 14.4ms	remaining: 707ms
# 2:	learn: 0.5093924	total: 19.6ms	remaining: 635ms
# 3:	learn: 0.4674833	total: 29.6ms	remaining: 712ms
# 4:	learn: 0.4320377	total: 41.3ms	remaining: 785ms
# 5:	learn: 0.4020031	total: 48.9ms	remaining: 767ms
# 6:	learn: 0.3763132	total: 57.4ms	remaining: 762ms
# 7:	learn: 0.3544087	total: 64ms	remaining: 736ms
# 8:	learn: 0.3354976	total: 70.2ms	remaining: 710ms
# 9:	learn: 0.3190759	total: 76.7ms	remaining: 690ms
# 10:	learn: 0.3050207	total: 89.7ms	remaining: 725ms
# 11:	learn: 0.2927704	total: 98.6ms	remaining: 723ms
# 12:	learn: 0.2819552	total: 106ms	remaining: 706ms
# 13:	learn: 0.2728008	total: 112ms	remaining: 689ms
# 14:	learn: 0.2648100	total: 119ms	remaining: 677ms
# 15:	learn: 0.2580216	total: 125ms	remaining: 659ms
# 16:	learn: 0.2520083	total: 133ms	remaining: 652ms
# 17:	learn: 0.2466680	total: 140ms	remaining: 639ms
# ...

# %%
from sklearn.metrics import accuracy_score
y_pred=model.predict(x_test) # Predict on the testing data

accuracy = accuracy_score(y_test, y_pred) #model performance

print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9436985047299359
